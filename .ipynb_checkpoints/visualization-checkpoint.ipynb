# %%
import pandas as pd
import numpy as np
from string import ascii_letters
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_colwidth', None)
pd.options.display.float_format = '{:,.2f}'.format

# %%
data = pd.read_csv("beatles.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_name', 'track_number',
#        'short_album_name', 'release_date', 'album_cover', 'duration_seconds',
#        'track1', 'last_track'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0'],inplace=True, axis=1)

# %%
data.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'track_name', 'track_number', 'short_album_name',
#        'release_date', 'album_cover', 'duration_seconds', 'track1',
#        'last_track'],
#       dtype='object')

# %% [markdown]
# # Coorelation plot

# %%
numdata = data[['danceability','energy','key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'time_signature','track_number','duration_seconds','track1', 'last_track']]

# %%
sns.set_theme(style="white")
corr = numdata.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
plt.savefig('heatmap.png')

# %% [markdown]
# #  Histograms

# %%
sns.displot(x = data['duration_seconds'], bins = 20)
sns.displot(x = data['energy'], bins = 20)
sns.displot(x = data['key'], bins = 5)
sns.displot(x = data['danceability'], bins = 10)

# %%
sns.displot(x = data['loudness'], bins = 10)
sns.displot(x = data['speechiness'], bins = 10)
sns.displot(x = data['acousticness'], bins = 10)
sns.displot(x = data['instrumentalness'], bins = 10)

# %%
sns.displot(x = data['liveness'], bins = 10)
sns.displot(x = data['tempo'], bins = 10)
sns.displot(x = data['valence'], bins = 10)
sns.displot(x = data['time_signature'], bins = 3)

# %%
stat1=round(data.describe().T,3)
stat1.rename(columns = {'50%': 'median'}, inplace= True)
stat1
# Out:
#                   count   mean   std    min    25%  median    75%    max
# danceability     190.00   0.53  0.14   0.17   0.42    0.54   0.61   0.91
# energy           190.00   0.54  0.19   0.09   0.42    0.55   0.68   0.97
# key              190.00   4.70  3.40   0.00   2.00    4.00   7.00  11.00
# loudness         190.00  -9.74  2.78 -23.03 -10.78   -9.25  -8.15  -5.22
# mode             190.00   0.81  0.40   0.00   1.00    1.00   1.00   1.00
# speechiness      190.00   0.05  0.03   0.03   0.03    0.04   0.05   0.21
# acousticness     190.00   0.38  0.28   0.00   0.12    0.34   0.63   0.97
# instrumentalness 190.00   0.07  0.20   0.00   0.00    0.00   0.00   0.93
# liveness         190.00   0.22  0.18   0.04   0.10    0.15   0.29   0.91
# valence          190.00   0.64  0.25   0.04   0.47    0.69   0.84   0.97
# tempo            190.00 121.63 27.78  59.00 100.54  122.39 135.96 209.24
# time_signature   190.00   3.86  0.47   1.00   4.00    4.00   4.00   5.00
# ...
