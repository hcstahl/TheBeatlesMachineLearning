# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import KMeans
import numpy as np

# %% [markdown]
# # Convert images to an Array

# %%
Yellow= cv2.imread("YellowSub.jpg");

# %%
plt.imshow(Yellow)

# %% [markdown]
# # Converting to normal color

# %%
Yellow = cv2.cvtColor(Yellow, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Displaying Image

# %%
plt.imshow(Yellow)

# %% [markdown]
# # Convert image to 2D
#  for the cv2.kmeans() function

# %%
# reshape the image to a 2D array of pixels and 3 color values (RGB)

Yellowpixel = Yellow.reshape((-1, 3))

# %% [markdown]
# # Convert to Float

# %%
Yellowpixel = np.float32(Yellowpixel)

# %%
print(Yellowpixel.shape)
# Out:
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)
# (409600, 3)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 200, 0.2)

# %% [markdown]
# # Yellow Submarine Cover

# %%
k_Yellow = 3
_, labels, (centers) = cv2.kmeans(Yellowpixel, k, None, criteria, 5, cv2.KMEANS_RANDOM_CENTERS)

# %%
centers = np.uint8(centers)
labels = labels.flatten()

# %%
# convert all pixels to the color of the centroids
segmented_image = centers[labels.flatten()]

# %%
# reshape back to the original image dimension
segmented_image = segmented_image.reshape(Yellow.shape)
# show the image
plt.imshow(segmented_image)
plt.show()

# %% [markdown]
# Normal Image
# k = 3 is minimum amount of clusters that make the normal image color

# %%
masked_image = np.copy(Yellow)
# convert to the shape of a vector of pixel values
masked_image = masked_image.reshape((-1, 3))
# color (i.e cluster) to disable
cluster = 3
masked_image[labels == cluster] = [0, 0, 0]
# convert back to original shape
masked_image = masked_image.reshape(Yellow.shape)

plt.imshow(masked_image)
plt.show()

# %% [markdown]
# A higher k just produces the same image as before wiht k = 3

# %%
# disable only the cluster number 3 (turn the pixel into black)
masked_image = np.copy(Yellow)
# convert to the shape of a vector of pixel values
masked_image = masked_image.reshape((-1, 3))
# color (i.e cluster) to disable
cluster = 4
masked_image[labels == cluster] = [0, 0, 0]
# convert back to original shape
masked_image = masked_image.reshape(Yellow.shape)


plt.imshow(masked_image)
plt.show()

# %% [markdown]
# What the image looks like reduced to k = 2

# %%
masked_image = np.copy(Yellow)
# convert to the shape of a vector of pixel values
masked_image = masked_image.reshape((-1, 3))
# color (i.e cluster) to disable
cluster = 2
masked_image[labels == cluster] = [0, 0, 0]
# convert back to original shape
masked_image = masked_image.reshape(Yellow.shape)


plt.imshow(masked_image)
plt.show()

# %% [markdown]
# What the image looks like reduced to k = 1

# %%
# disable only the cluster number 3 
masked_image = np.copy(Yellow)
# convert to the shape of a vector of pixel values
masked_image = masked_image.reshape((-1, 3))
# color (i.e cluster) to disable
cluster = 1
masked_image[labels == cluster] = [0, 0, 0]
# convert back to original shape
masked_image = masked_image.reshape(Yellow.shape)


plt.imshow(masked_image)
plt.show()

# %%
What the image looks like reduced to k = 0

# %%
# disable only the cluster number 3 (turn the pixel into black)
masked_image = np.copy(Yellow)
# convert to the shape of a vector of pixel values
masked_image = masked_image.reshape((-1, 3))
# color (i.e cluster) to disable
cluster = 0
masked_image[labels == cluster] = [0, 0, 0]
# convert back to original shape
masked_image = masked_image.reshape(Yellow.shape)


plt.imshow(masked_image)
plt.show()

# %% [markdown]
# # Abbey Road

# %%
AR=  cv2.imread("AbbeyRoad.jpg");

# %%
plt.imshow(AR)

# %%
AR = cv2.cvtColor(AR, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(AR)

# %%
ARpixel = AR.reshape((-1, 3))

# %%
ARpixel = np.float32(ARpixel)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 200, 0.2)

# %%
k_AR = 6
_, labels, (centers) = cv2.kmeans(ARpixel, k, None, criteria, 5, cv2.KMEANS_RANDOM_CENTERS)

# %%
centers = np.uint8(centers)
labels = labels.flatten()
segmented_image2 = centers[labels.flatten()]

# %%
segmented_image2 = segmented_image2.reshape(AR.shape)
# show the image
plt.imshow(segmented_image2)
plt.show()

# %% [markdown]
# With only one cluster

# %%
masked_image = np.copy(AR)
# convert to the shape of a vector of pixel values
masked_image = masked_image.reshape((-1, 3))
# color (i.e cluster) to disable
cluster = 1
masked_image[labels == cluster] = [0, 0, 0]
# convert back to original shape
masked_image = masked_image.reshape(AR.shape)

plt.imshow(masked_image)
plt.show()

# %% [markdown]
# With 2 clusters

# %%
masked_image = np.copy(AR)
# convert to the shape of a vector of pixel values
masked_image = masked_image.reshape((-1, 3))
# color (i.e cluster) to disable
cluster = 2
masked_image[labels == cluster] = [0, 0, 0]
# convert back to original shape
masked_image = masked_image.reshape(AR.shape)

plt.imshow(masked_image)
plt.show()
