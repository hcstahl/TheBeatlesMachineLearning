# %%
import cv2
from matplotlib.image import imread
import matplotlib.pyplot as plt

# %%
PPM = cv2.imread("PleasePleaseMe.jpg");
BFS = cv2.imread("BeatlesForSale.jpg");
HDN = cv2.imread("AHardDaysNight.jpg");
AR = cv2.imread("AbbeyRoad.jpg");
Help= cv2.imread("Help.jpg");
LIB= cv2.imread("LetItBe.jpg");
MMT= cv2.imread("Mystery.jpg");
RS= cv2.imread("RubberSoul.jpg");
Revolver= cv2.imread("Revolver.jpg");                    
Sgt= cv2.imread("SgtPepper.jpg"); 
WTB= cv2.imread("WithTheBeatles.jpg"); 
Yellow= cv2.imread("YellowSub.jpg");

# %% [markdown]
# # Convert to Gray
# Function uses gray scale only

# %%
PPM= cv2.cvtColor(PPM,cv2.COLOR_BGR2GRAY)
BFS = cv2.cvtColor(BFS,cv2.COLOR_BGR2GRAY)
HDN= cv2.cvtColor(HDN,cv2.COLOR_BGR2GRAY)
AR= cv2.cvtColor(AR,cv2.COLOR_BGR2GRAY)
Help= cv2.cvtColor(Help,cv2.COLOR_BGR2GRAY)
LIB= cv2.cvtColor(LIB,cv2.COLOR_BGR2GRAY)
MMT= cv2.cvtColor(MMT,cv2.COLOR_BGR2GRAY)
RS= cv2.cvtColor(RS,cv2.COLOR_BGR2GRAY)
Revolver= cv2.cvtColor(Revolver,cv2.COLOR_BGR2GRAY)
Sgt= cv2.cvtColor(Sgt,cv2.COLOR_BGR2GRAY)
WTB= cv2.cvtColor(WTB,cv2.COLOR_BGR2GRAY)
Yellow= cv2.cvtColor(Yellow,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(RS)

# %% [markdown]
# # Face Regonition

# %% [markdown]
# # Detect all the faces in the image
